# %% [markdown]
# # Project TBD

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./sunspot_data/daily_ssn.txt', delimiter='\s+', skiprows=1)

# %%
data
# Out:
#        Year  Month  Day   SSN
# 0      1945      1    1  10.0
# 1      1945      1    2   0.0
# 2      1945      1    3   1.0
# 3      1945      1    4   2.0
# 4      1945      1    5  11.0
# ...     ...    ...  ...   ...
# 26658  2017     12   27   NaN
# 26659  2017     12   28   NaN
# 26660  2017     12   29   NaN
# 26661  2017     12   30   NaN
# 26662  2017     12   31   NaN
#
# [26663 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
plt.scatter(range(len(data['SSN'])), data['SSN'], s=4)
