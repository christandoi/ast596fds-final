# %% [markdown]
# # Project TBD

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
noaa = pd.read_csv('./sunspot_data/NOAA_daily_1945.txt', delimiter='\s+', skiprows=1)
silso1818 = pd.read_csv('./sunspot_data/SILSO_daily_1818.csv', delimiter=';')

silso1818.columns = ['Year', 'Month', 'Day', 'Decimal year', 'SSN', 'Stdev', 'No. of observations', 'Definitivate/provisional']

# %%
noaa
# Out:
#        Year  Month  Day   SSN
# 0      1945      1    1  10.0
# 1      1945      1    2   0.0
# 2      1945      1    3   1.0
# 3      1945      1    4   2.0
# 4      1945      1    5  11.0
# ...     ...    ...  ...   ...
# 26658  2017     12   27   NaN
# 26659  2017     12   28   NaN
# 26660  2017     12   29   NaN
# 26661  2017     12   30   NaN
# 26662  2017     12   31   NaN
#
# [26663 rows x 4 columns]

# %%
silso1818
# Out:
#        Year  Month  Day  Decimal year  SSN  Stdev  No. of observations  \
# 0      1818      1    2      1818.004   -1   -1.0                    0
# 1      1818      1    3      1818.007   -1   -1.0                    0
# 2      1818      1    4      1818.010   -1   -1.0                    0
# 3      1818      1    5      1818.012   -1   -1.0                    0
# 4      1818      1    6      1818.015   -1   -1.0                    0
# ...     ...    ...  ...           ...  ...    ...                  ...
# 73864  2020      3   27      2020.236    0    0.0                   43
# 73865  2020      3   28      2020.239    0    0.0                   39
# 73866  2020      3   29      2020.242    0    0.0                   36
# 73867  2020      3   30      2020.245    4    0.2                    9
# 73868  2020      3   31      2020.247   12    1.0                   31
#
#        Definitivate/provisional
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 73864                         0
# 73865                         0
# 73866                         0
# 73867                         0
# 73868                         0
#
# [73869 rows x 8 columns]

# %%
plt.figure(figsize=(20,10))
plt.title('NOAA sunspot numbers 1945-2017')
plt.scatter(range(len(noaa['SSN'])), noaa['SSN'], s=4)

#only goes back to 1945, not enough data?

# %%
plt.figure(figsize=(20,10))
plt.title('WDC-SILSO sunspot numbers 1818-2020')
plt.scatter(range(len(silso1818['SSN'])), silso1818['SSN'], s=4)

#note: value of -1 means no data collected that day. need to cut out
